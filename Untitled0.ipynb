# %%
#update value in list
A=[10,2,3,4,5,66]
A[0]=100
print(A)
# Out:
# [100, 2, 3, 4, 5, 66]

# %%
#sets1
s1={1,4,5,66,5,32}
print(s1)
# Out:
# {32, 1, 66, 4, 5}

# %%
# add element into set
s1={2,4,5,6,78}
s2={3,56,78,90,23}
s=set(zip(s1,s2))
print(s)
# Out:
# {(78, 78), (4, 23), (5, 56), (2, 3), (6, 90)}

# %%
# Tuples
A=(19,10,44,56,90)
print(A)
# Out:
# (19, 10, 44, 56, 90)

# %%
#silcing
A="shiva","mani","konda","binnu"
print("A[0] element is:",A[0:])
# Out:
# A[0] element is: ('shiva', 'mani', 'konda', 'binnu')

# %%
# create a empty tuple
A=()
print(A)
# Out:
# ()

# %%
#convert a given tuple into list
A=(91,"shiva",45,"shan",78)
Y=list(A)
#print(Y)
Y.append(10)
print(Y)
# Out:
# [91, 'shiva', 45, 'shan', 78, 10]

# %%
 # operations in tuples
 A=('mani',"shiva","shan",'ksai')
 B="shiva","mani","konda","binnu"
 print(max(A))
 print(len(A))
 print(A+B)
# Out:
# shiva
# 4
# ('mani', 'shiva', 'shan', 'ksai', 'shiva', 'mani', 'konda', 'binnu')
