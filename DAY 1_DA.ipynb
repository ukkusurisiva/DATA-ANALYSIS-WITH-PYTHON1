# %%
# varible
a=10
print("i am", a, "years old")
# Out:
# i am 10 years old

# %%
# arthimatic of  two int variable
a=int(input("enter a  values"))
b=int(input("enter b value"))
c=a+b
d=b-a
p=a*b
print("Sum is",c)
print("difference is is",d)
print("product is",p)
print("remainder is",(a%b))
print("quotient is",(a/b))
print("power  is",pow(a,b))
print("floor is",a//b)
# Out:
# enter a  values5
# enter b value8
# Sum is 13
# difference is is 3
# product is 40
# remainder is 5
# quotient is 0.625
# power  is 390625
# floor is 0

# %%
# create take a no. from the user salary.if the salary is more than 50,000 there is 10% tax print his final salarry.
s=int(input("enter the salary"))
tax=s*10/100
if s>=50000:
  v=s-tax
  print("tax is",v)
else:
    print("there is no tax and salarry is",s)
# Out:
# enter the salary1200
# there is no tax and salarry is 1200

# %%
#get the salarry from the user if salarry is more or equal to 50000 apply 10@ tax detection if the salarry is lessthan 50000 apply 5@ tax if the salarry is more than 70K apply 12@ tax
#if the salarry exsits 1L print your promoted to next level
sal=int(input("enter the salary"))
if sal<=50000:
  print("salarry is",sal-(sal*5/100))
elif sal>50000 and sal<=70000:
  print("salarry is ",sal-(sal*10/100))
elif sal>70000 and sal<=100000:
  print("salarry is",sal-(sal*12/100))
elif sal==0:
  print("enter anthore choice")
  print("your are promoted to next level")
# Out:
# enter the salary75000
# salarry is 66000.0

# %%
for i in range(0,11):

  print("10 X",i,"=",10*i)
# Out:
# 10 X 0 = 0
# 10 X 1 = 10
# 10 X 2 = 20
# 10 X 3 = 30
# 10 X 4 = 40
# 10 X 5 = 50
# 10 X 6 = 60
# 10 X 7 = 70
# 10 X 8 = 80
# 10 X 9 = 90
# 10 X 10 = 100

# %%
# printing of squares
a=int(input("enter the number"))
for i in range(1,a):
  print("squres of a number is",i**2)
# Out:
# enter the number15
# squres of a number is 1
# squres of a number is 4
# squres of a number is 9
# squres of a number is 16
# squres of a number is 25
# squres of a number is 36
# squres of a number is 49
# squres of a number is 64
# squres of a number is 81
# squres of a number is 100
# squres of a number is 121
# squres of a number is 144
# squres of a number is 169
# squres of a number is 196

# %%
#while
n=int(input("enter the number "))
i=1
while (i<11):
  print(n,"x",i,"=",n*i)
  i=i+1
# Out:
# enter the number 7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %%
#create a  hetrogenus list
l1=[10,"shiva",4.6,True]
for i in l1:
  print(i)
# Out:
# 10
# shiva
# 4.6
# True

# %%
#append
l1.append(8) #adds elements at end of list
print(l1)
# Out:
# [10, 'shiva', 4.6, True, 8]

# %%
#insert
l1.insert(3,'hi') #listname.insert(index,element)
print(l1)
# Out:
# [10, 'shiva', 4.6, 'hi', 4, True, 8, 'subu', 9, 'dileep', 5.7, True, 'raju']

# %%
l2=['subu',9,'dileep',5.7,True]
l2.insert(5,"raju")
print(l2)
# Out:
# ['subu', 9, 'dileep', 5.7, True, 'raju']

# %%
print(l1+l2)
# Out:
# [10, 'shiva', 4.6, 4, True, 8, 'subu', 9, 'dileep', 5.7, True, 'raju']

# %%
l1.extend(l2)
print(l1)
# Out:
# [10, 'shiva', 4.6, 4, True, 8, 'subu', 9, 'dileep', 5.7, True, 'raju']

# %%
l1.pop(1) # poped element at  position
print(l1)
# Out:
# [10, 'hi', 4, True, 8, 'subu', 9, 'dileep', 5.7, True, 'raju']

# %%
# remove element
l1.remove(True)
print(l1)
# Out:
# [10, 4, 8, 'subu', 9, 'dileep', 5.7, True, 'raju']

# %%
#clear
l1.clear()
print(l1)
# Out:
# []

# %%
# create list of 10 integer  elementsand print there squers save these squares in a new list
l6=[1,2,3,4,6,7,8,98,74] #LC
l7=[i*i for i in l6] #[NEW LIST]=[OUT PUT LIST]
print(l7)
# Out:
# [1, 4, 9, 16, 36, 49, 64, 9604, 5476]

# %%
l8=[i*i for i in l6 ]
if i>50 in l8:
  print(l8)
